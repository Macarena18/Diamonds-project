# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
diamonds= pd.read_csv("../input_diamonds/diamonds_train.csv")
diamonds.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           0   1.21      Ideal     H     VS2   63.0   57.0  6.73  6.70  4.23
# 1           1   0.28  Very Good     D    VVS2   64.0   56.0  4.14  4.17  2.66
# 2           2   0.42    Premium     F     VS1   61.2   58.0  4.86  4.82  2.96
# 3           3   0.26      Ideal     H      IF   61.1   57.0  4.16  4.12  2.53
# 4           4   1.10       Good     G     SI1   63.4   57.0  6.52  6.55  4.14
#
#    price
# 0   6134
# 1    532
# 2   1103
# 3    600
# 4   4997

# %% [markdown]
# **Convert categorical to numerical:**

# %%
diamonds["cut"].value_counts()
# Out:
# Ideal        16090
# Premium      10339
# Very Good     9036
# Good          3694
# Fair          1186
# Name: cut, dtype: int64

# %%
diamonds["cut"].replace(["Premium", "Ideal", "Very Good","Good","Fair"],[1,2,3,4,5],inplace=True)
diamonds["cut"].value_counts()
# Out:
# 2    16090
# 1    10339
# 3     9036
# 4     3694
# 5     1186
# Name: cut, dtype: int64

# %%
diamonds["color"].value_counts()
# Out:
# G    8499
# E    7351
# F    7130
# H    6234
# D    5074
# I    4023
# J    2034
# Name: color, dtype: int64

# %%
diamonds["color"].replace(["G", "E", "F","H","D","I","J"],[1,2,3,4,5,6,7],inplace=True)
diamonds["color"].value_counts()
# Out:
# 1    8499
# 2    7351
# 3    7130
# 4    6234
# 5    5074
# 6    4023
# 7    2034
# Name: color, dtype: int64

# %%
diamonds["clarity"].value_counts()
# Out:
# SI1     9751
# VS2     9178
# SI2     6828
# VS1     6101
# VVS2    3858
# VVS1    2714
# IF      1362
# I1       553
# Name: clarity, dtype: int64

# %%
diamonds["clarity"].replace(["SI1", "VS2", "SI2","VS1","VVS2","VVS1","IF","I1"],[1,2,3,4,5,6,7,8],inplace=True)
diamonds["clarity"].value_counts()
# Out:
# 1    9751
# 2    9178
# 3    6828
# 4    6101
# 5    3858
# 6    2714
# 7    1362
# 8     553
# Name: clarity, dtype: int64

# %%
diamonds=diamonds[(diamonds.x!=0) & (diamonds.y!=0) & (diamonds.z!=0)]
diamonds
# Out:
#        Unnamed: 0  carat  cut  color  clarity  depth  table     x     y     z  \
# 0               0   1.21    2      4        2   63.0   57.0  6.73  6.70  4.23
# 1               1   0.28    3      5        5   64.0   56.0  4.14  4.17  2.66
# 2               2   0.42    1      3        4   61.2   58.0  4.86  4.82  2.96
# 3               3   0.26    2      4        7   61.1   57.0  4.16  4.12  2.53
# 4               4   1.10    4      1        1   63.4   57.0  6.52  6.55  4.14
# ...           ...    ...  ...    ...      ...    ...    ...   ...   ...   ...
# 40340       40340   1.55    1      4        2   61.3   61.0  7.46  7.39  4.55
# 40341       40341   0.36    2      5        1   60.6   56.0  4.58  4.63  2.79
# 40342       40342   0.57    3      6        2   62.2   55.0  5.33  5.34  3.32
# 40343       40343   1.01    3      3        7   59.6   62.0  6.47  6.56  3.88
# 40344       40344   0.54    2      2        3   60.4   57.0  5.33  5.27  3.20
#
#        price
# 0       6134
# 1        532
# 2       1103
# 3        600
# 4       4997
# ...      ...
# 40340  11708
# 40341    619
# 40342   1267
# 40343   9965
# 40344   1340
#
# [40328 rows x 11 columns]

# %% [markdown]
# **Remove columns correlated:**

# %%
corr = diamonds.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col2 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col3 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col5 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col6 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col7 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col8 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col9 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row0_col10 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col3 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col5 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col6 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col7 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col8 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col9 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row1_col10 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col1 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col3 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col4 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col5 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col6 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col7 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col8 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col9 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row2_col10 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col1 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col4 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col6 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col7 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col8 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col9 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row3_col10 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col6 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row4_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row5_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row5_col1 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row5_col2 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row5_col3 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_27aaa8bc_91ff_11ea_9ad0_acde48001122row5_col4 {
#             background-color:  #6687ed;
#             color:  #000000

# %%
diamonds.drop(columns=["x","z","Unnamed: 0"],inplace=True) # esta vez no elimino todas

# %%
X=diamonds.drop(columns=["price"])
y=diamonds["price"]

# %%
pca = PCA(n_components=7)
XReduced = pd.DataFrame(pca.fit_transform(X))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (32262, 7) (8066, 7) (32262,) (8066,)

# %% [markdown]
# # RandomForest:

# %%
model= RandomForestRegressor(n_estimators=500).fit(X_train, y_train)
y_pred=model.predict(X_test)
print(np.mean(cross_val_score(model, X_train, y_train, scoring='r2', cv=3, n_jobs=2)))
print("r2_score", r2_score(y_test,y_pred))
print("RSME", (mean_squared_error(y_test,y_pred)**0.5))

# n_estimator:1500
#0.9786474761729842
#r2_score 0.9790276359720973
#RSME 583.9631151711887

#100:
#0.9785539470544492
#r2_score 0.979053221526376
#RSME 583.6067991253947
# Out:
# 0.9783305822469474
# r2_score 0.9786958535541257
# RSME 588.5641325112016

# %%
diamonds_test = pd.read_csv("../input_diamonds/diamonds_test.csv")
diamonds_test.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z
# 0           0   0.30      Ideal     H     SI2   60.0   56.0  4.41  4.43  2.65
# 1           1   0.34      Ideal     D      IF   62.1   57.0  4.52  4.46  2.79
# 2           2   1.57  Very Good     I     VS2   60.3   58.0  7.58  7.55  4.56
# 3           3   0.31      Ideal     H     VS2   61.8   57.0  4.32  4.36  2.68
# 4           4   1.51       Good     I    VVS1   64.0   60.0  7.26  7.21  4.63

# %%
diamonds_test.drop(columns=['x','z',"Unnamed: 0"],inplace=True)

# %%
diamonds_test["cut"].replace(["Premium", "Ideal", "Very Good","Good","Fair"],[1,2,3,4,5],inplace=True)
diamonds_test["color"].replace(["G", "E", "F","H","D","I","J"],[1,2,3,4,5,6,7],inplace=True)
diamonds_test["clarity"].replace(["SI1", "VS2", "SI2","VS1","VVS2","VVS1","IF","I1"],[1,2,3,4,5,6,7,8],inplace=True)

# %%
price_pred=model.predict(diamonds_test)

# %%
df_price=pd.DataFrame({'price':price_pred})
df_price.index.rename('id', inplace=True)
df_price.head()
# Out:
#        price
# id
# 0    428.172
# 1   1821.570
# 2   9859.576
# 3    545.900
# 4   9287.800

# %%
df_price.to_csv("./output/test4.csv")

# %% [markdown]
# # GradientBoosting

# %%
model2= GradientBoostingRegressor(n_estimators=2000).fit(X_train, y_train)
y_pred=model2.predict(X_test)
print(np.mean(cross_val_score(model2, X_train, y_train, scoring='r2', cv=3, n_jobs=2)))
print("r2_score", r2_score(y_test,y_pred))
print("RSME", (mean_squared_error(y_test,y_pred)**0.5)) 

#700= 631.92
#1000=628
#1500=619
# Out:
# 0.9770999909911752
# r2_score 0.9765974173560159
# RSME 616.8699529634123

# %%
price_pred=model2.predict(diamonds_test)

# %%
df2_price=pd.DataFrame({'price':price_pred})
df2_price.index.rename('id', inplace=True)
df2_price.head()
# Out:
#            price
# id
# 0     272.568900
# 1    1949.103375
# 2    9909.539672
# 3     593.909027
# 4   10780.397148

# %%
df2_price.to_csv("./output/test5.csv")
